# %% [markdown]
# # Setting up Your Analytics Stack with Jupyter Notebook & AWS Redshift

# %% [markdown]
# In this blog post I will walk you though the exact steps needed to set up Jupyter Notebook to connect to your private data warehouse in AWS Redshift.
#
# At RJMetrics, I use the Jupyter + Redshift analytics stack every single day because there are truly very few limits to what one can do with this powerful combination. From querying your data and visualizing it all in one place, to documenting your work and building interactive charts and dashboards, to running machine learning algorithms on top of your data and sharing the results with your team, the possibilities are limitless.
#
# This entire post was written in Jupyter itself so that you can:
# <ol>
#     <li>see how easy it is to get started,
#     <li><a href="https://github.com/3mei/rjmetrics_blog_posts/tree/master/jupyter_redshift_analytics_stack">download the notebook</a> to follow along on your computer, and
#     <li>modify the code so that you can start analyzing your own data.
# </ol>
#
# Let's get started!

# %% [markdown]
# ## What is Jupyter Notebook?

# %% [markdown]
# <img src='assets/jupyter.png'>

# %% [markdown]
# <a href="https://jupyter.org/">Jupyter Notebook</a> is an **open-source** data science tool used by many data scientists and data analysts at some of the most data-driven organizations in the world, including Google, Microsoft, IBM, Bloomberg, O'Reilly and NASA.
#
# An extension of the <a href="http://ipython.org/">IPython project</a>, Jupyter Notebook is an application that runs directly in your browser and allows you to create and share documents with live code from over 40 different languages. You can also supplement these documents with explanatory text, equations, and rich visualizations.
#
# Working with Jupyter is literally like writing a notebook. You can document your work, make it accessible to other people and easily reproduce it in the future. Once the notebook is set up, you can readily share it with others. For example, GitHub <a href="https://github.com/blog/1995-github-jupyter-notebooks-3">natively renders</a> notebook files as soon as they are committed into a repository. Alternatively, you can export your notebook into a number of different formats, including PDF, HTML, Markdown, and reST.
#
# Combined with its open-source nature, big data integration capabilities (e.g., Apache Spark via Python, R, or Scala), and the ability to execute code in virtually any language of your choice, Jupyter Notebook is particularly well-suited for exploring data, experimenting with it, and capturing entire data-driven workflows (see also our <a href="https://blog.rjmetrics.com/2015/12/06/data-science-roundup-11-data-ethics-the-field-guide-to-data-science-and-solving-the-data-scientist-shortage/">Data Science Roundup #11</a> discussing the recent rise of notebooks).

# %% [markdown]
# #### <a id='installing_jupyter'></a>Installing Jupyter and Python

# %% [markdown]
# If you have never worked with Jupyter before or if you are not sure whether it is installed on your machine, please take a look at this brief <a href="http://jupyter.readthedocs.org/en/latest/install.html">installation article</a> from the developers of Jupyter. Several Python distributions (e.g., Anaconda) conveniently ship with both Python and Jupyter.

# %% [markdown]
# ## What is AWS Redshift?

# %% [markdown]
# <a href="https://aws.amazon.com/redshift/">Amazon Redshift</a> is a fast, fully managed, petabyte-scale data warehouse. With Redshift, it has never been easier or more cost-effective to securely store your data in the cloud. On-demand pricing means that you can get started for as little as 25 cents an hour and you don't have to worry about backup, durability, availability, security, monitoring, or maintenance: AWS takes care of all of that for you.
#
# Because of its ease of use, Redshift is experiencing <a href="https://blog.rjmetrics.com/2015/10/29/how-aws-redshift-is-opening-up-big-data-to-growth-hackers-marketers-and-other-light-quants/">rapid adoption</a> among light quants, growth hackers, seasoned analysts and data scientists. It integrates seamlessly with the languages you may be already familiar with, including SQL, R, and Python. For the purpose of this post, I will be focusing on the latter.

# %% [markdown]
# #### Setting Up Your AWS Redshift Instance

# %% [markdown]
# To access you Redshift instance, you will need to know your (i) user name, (ii) password, (iii) host name, (iv) port and (v) database name. If you personally set up your Redshift instance, you will already know what these are. If not, please ask someone who did or take a look at the AWS documentation on how to obtain these credentials. Note that the port number for AWS Redshift is 5439.

# %% [markdown]
# ## 1. Install Requirements

# %% [markdown]
# Please make sure Jupyter and Python are setup on your computer (see <a href='#installing_jupyter'>Installing Jupyter and Python</a> above).
#
# We will need to install a few packages in order to connect to and work with AWS Redshift. Note that depending on your Python distribution, you may need to install additional packages. I recommend that you use the completely free <a href="https://www.continuum.io/why-anaconda">Anaconda distribution</a> as it already comes with many of the required packages installed and the packages are tested and guaranteed to work together. If working with Anaconda, you can use the built-in package management system `conda`. Alternatively, you can use Python's built-in <a href="https://pip.pypa.io/en/stable/installing/">pip</a> package management system or <a href="http://brew.sh/">Homebrew</a> (OS X only).
#
# I will use a combination of Homebrew and pip in the following. Note that you may need to use pip3 if working with Python versions 3.3 or later.

# %% [markdown]
# <ol>
#     <li>
#         <b>Install PostgreSQL</b>
#         <br>First, since Amazon Redshift is based on PostgreSQL 8.0.2, we will need a PostgreSQL client library.<br><br>
#         If using Mac OS X, simply simply open up your terminal and type &nbsp;&nbsp; `brew install postgresql`<br><br>
#         For other operating systems, please see the installation instructions <a href="http://www.postgresql.org/download/">here</a>.<br><br>
#     </li>
#
#     <li>
#         <b>Install Python Requirements</b>
#         <br>Second, we will need a few python packages to connect to and get data from Redshift.
#
#
#         You can simply download the `requirements.txt` file, navigate to the folder containing it and type &nbsp;&nbsp; `pip install -r redshift_requirements.txt`.<br><br>
#
#         (Pro tip: you may want to create a virtual python environment to keep the package dependencies required by different projects in separate locations. See <a href="http://docs.python-guide.org/en/latest/dev/virtualenvs/">Python</a> and <a href="http://conda.pydata.org/docs/_downloads/conda-pip-virtualenv-translator.html">Conda</a> documentation for more details.)<br><br>
#
#
#         Here is a brief description of the four packages included in `redshift_requirements.txt`:
#         <ul>
#             <li><a href="http://initd.org/psycopg/">Psycopg2</a>: Python adapter needed to connect to Redshift.</li>
#
#             <li><a href="http://www.sqlalchemy.org/">SQLAlchemy</a>: Python SQL toolkit and Object Relational Mapper that provides an efficient way to access a database.</li>
#
#             <li><a href="https://github.com/catherinedevlin/ipython-sql">iPython-SQL</a>: provides a straightforward way to write SQL and get data back. Introduces magic commands `%sql` and `%%sql` so that you can write plain SQL and get back your query results in the form of a dataframe.</li>
#
#             <li><a href="https://pypi.python.org/pypi/simplejson/">SimpleJSON</a>: simple and fast JSON encoder and decoder. We will store Redshift credentials in a JSON-formatted file and will make use of the package to read that file.</li>
#        </ul>
#    </li>
# </ol>

# %% [markdown]
# ## 2. Save your Redshift Credentials

# %% [markdown]
# To access you Redshift instance, you will need to know your (i) user name, (ii) password, (iii) host name, (iv) port and (v) database name. If you personally set up your Redshift instance, you will already know what these are. If not, please ask someone who did or take a look at the <a href="http://docs.aws.amazon.com/redshift/latest/mgmt/connecting-via-client-tools.html">AWS documentation</a> on how to obtain these credentials. Note that the port number for AWS Redshift is 5439.
#
# So that you don't expose any of the sensitive information above in your Notebook (e.g, when sharing your notebook with other people or when storing your notebook in a GitHub repository), please save your Redshift credentials inside a JSON-formatted file called `redshift_creds.json.nogit`. You can download the template for that file <a href="https://github.com/3mei/rjmetrics_blog_posts/tree/master/jupyter_redshift_analytics_stack/assets/redshift_creds.json.nogit">here</a>. The contents of the file is pretty self-explanatory:

# %% [markdown]
# <img src='assets/redshift_creds.png'>

# %% [markdown]
# I would suggest saving the `redshift_creds.json.nogit` file in a folder that is separate from the one with your Jupyter file in it so that you don't accidentally store the credentials on GitHub. For extra security, you can specify the `*.nogit` pattern in the <a href="http://git-scm.com/docs/gitignore">.gitingore file</a> of your repository.

# %% [markdown]
# ## 3. Whitelist your IP address in the AWS Panel

# %% [markdown]
# By default, your Redshift cluster is locked down so that nobody has access to it. You can grant people **inbound access** to your cluster via the AWS panel by creating a security group and specifying which IP addresses are allowed to connect to Redshift. Makes sure that your IP address is included in one of these rules. Please see the <a href="http://docs.aws.amazon.com/redshift/latest/mgmt/working-with-security-groups.html">Amazon Redshift Cluster Security Groups</a> documentation from AWS for more details.

# %% [markdown]
# ## 4. Connect to Redshift!

# %% [markdown]
# You are now all set to connect to your Redshift instance! To do so from Jupyter, open up your terminal and type<br> `ipython notebook`
#
# This command will start up a notebook server in your console and open up a web browser to show you the Jupyter Notebook dashboard:

# %% [markdown]
# <img src='assets/jupyter_dashboard.png'>

# %% [markdown]
# You can then navigate to the folder containing this notebook (get it from GitHub <a href="https://github.com/3mei/rjmetrics_blog_posts/tree/master/jupyter_redshift_analytics_stack">here</a>) and click on the "jupyter_redshift_analytics_stack.ipynb" file to start up the exact notebook you are looking at right now.

# %% [markdown]
# Let's import the packages we just installed and load SQL magic. You can press `(shift + enter)` to execute the cell below.
#
# Note: if you are using anaconda and encounter the "Library not loaded: libssl.1.0.0.dylib" error when importing the psycopg2 package, run the following command in your terminal to add a fallback library path to your .bash_profile:<br>
# `sudo echo 'export DYLD_FALLBACK_LIBRARY_PATH=$HOME/anaconda/lib/:$DYLD_FALLBACK_LIBRARY_PATH' >>~/.bash_profile`

# %% [markdown]
# <b>for windows support for pyscopg - if using anaconda get source lib here: https://anaconda.org/anaconda/psycopg2
# may need to also run conda install -c conda-forge ipython-sql=0.3.6 to snyc versions<b>

# %%
import sqlalchemy
import psycopg2
import simplejson
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %load_ext sql
# %config SqlMagic.displaylimit = 5
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# <br>Next, let's read the credentials from file. Note that you will need to specify the path to the `redshift_creds.json.nogit` file on your machine.

# %%
with open("assets/redshift_creds.json.nogit") as fh:
    creds = simplejson.loads(fh.read())

# %%
creds
# Out:
# {'db_name': 'mktdb',
#  'host_name': 'marketing-dev.cx3gp2qyvmoy.us-east-1.redshift.amazonaws.com',
#  'password': 'Any1t!cs',
#  'port_num': '5439',
#  'user_name': 'dcm_power_user'}

# %% [markdown]
# <br>Finally, let's connect to Redshift!

# %%
connect_to_db = 'postgresql+psycopg2://' + \
                creds['user_name'] + ':' + creds['password'] + '@' + \
                creds['host_name'] + ':' + creds['port_num'] + '/' + creds['db_name'];
# %sql $connect_to_db
# Out:
# 'Connected: dcm_power_user@mktdb'

# %% [markdown]
# <br>
# As a simple test, let's get the current date and time from our Redshift instance:

# %%
# %%sql
# select getdate() as current_date
# Out:
# 1 rows affected.
# [(datetime.datetime(2018, 4, 10, 1, 54, 19),)]

# %% [markdown]
# We can now store the result in a dataframe by simply typing

# %%
df = _.DataFrame()
df
# Out:
#          current_date
# 0 2018-04-10 01:54:19

# %% [markdown]
# That's it!
#
# With only a few commands you loaded your Redshift credentials, connected to your data warehouse, executed a query and converted the query result into a pandas dataframe! Now the world is your oyster: you can use any package in the Python ecosystem to slice and dice a dataframe, visualize your results and share them with others.
#
# More on this in the blog posts to follow.

# %%
# %%sql
# select * from dcm.campaign_attributes limit 100
# Out:
# 100 rows affected.
# [('2 Dope Queens', None, 'Jumpstart', 'Default', 2, None, None, None, 0, '2 dope queens'),
#  ('All Def Comedy', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'all def comedy'),
#  ('Angry Boys', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'angry boys'),
#  ('Any Given Wednesday with Bill Simmons', None, 'Handoff', 'Default', 4, None, None, None, 1, 'any given wednesday with bill simmons'),
#  ('Ballers', None, 'Handoff', 'Default', 4, None, None, None, 1, 'ballers'),
#  ('Ballers', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'ballers'),
#  ('Big Little Lies', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'big little lies'),
#  ('Boardwalk Empire', None, 'Handoff', 'Default', 4, None, None, None, 1, 'boardwalk empire'),
#  ('Capadocia', None, 'Handoff', 'Default', 4, None, None, None, 1, 'capadocia'),
#  ('Carnivale', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'carnivale'),
#  ('Classical Baby', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'classical baby'),
#  ('Crashing', None, 'Jumpstart', 'Default', 4, 'current_season', None, None, 1, 'crashing'),
#  ("DANE COOK'S TOURGASM", None, 'Handoff', 'Default', 4, None, None, None, 1, "dane cook's tourgasm"),
#  ('Deadwood', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'deadwood'),
#  ('Deadwood', None, 'Handoff', 'Default', 4, None, None, None, 1, 'deadwood'),
#  ('Destino: Brazil', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'destino: brazil'),
#  ('Dios Inc.', None, 'Handoff', 'Default', 4, None, None, None, 1, 'dios inc.'),
#  ('Divorce', None, 'Handoff', 'Default', 1, None, None, None, 1, 'divorce'),
#  ('Eastbound & Down', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'eastbound & down'),
#  ('El Hipnotizador', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'el hipnotizador'),
#  ('El Jardin de Bronce', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'el jardin de bronce'),
#  ('El Jardin de Bronce', None, 'Handoff', 'Default', 4, None, None, None, 1, 'el jardin de bronce'),
#  ('El Negocio', None, 'Handoff', 'Default', 4, None, None, None, 1, 'el negocio'),
#  ('Epitafios', None, 'Handoff', 'Default', 4, None, None, None, 1, 'epitafios'),
#  ('Extras', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'extras'),
#  ('Fantasmagorias', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'fantasmagorias'),
#  ('Fraggle Rock', None, 'Handoff', 'Default', 4, None, None, None, 1, 'fraggle rock'),
#  ('Getting On', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'getting on'),
#  ('Girls', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'girls'),
#  ("Gran'pa Knows Best", None, 'Handoff', 'Default', 4, None, None, None, 1, "gran'pa knows best"),
#  ("Gran'pa Knows Best", None, 'Jumpstart', 'Default', 2, None, None, None, 1, "gran'pa knows best"),
#  ('HBO Storybook Musicals', None, 'Handoff', 'Default', 4, None, None, None, 1, 'hbo storybook musicals'),
#  ('HDP', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'hdp'),
#  ('Hello Ladies', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'hello ladies'),
#  ('Here and Now', None, 'Handoff', 'Default', 4, None, None, None, 1, 'here and now'),
#  ('Hijos del Carnaval', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'hijos del carnaval'),
#  ('Hijos del Carnaval', None, 'Handoff', 'Default', 4, None, None, None, 1, 'hijos del carnaval'),
#  ('Insecure', None, 'Handoff', 'Default', 4, None, None, None, 1, 'insecure'),
#  ("Ja'mie: Private School Girl", None, 'Jumpstart', 'Default', 2, None, None, None, 0, "ja'mie: private school girl"),
#  ('John From Cincinnati', None, 'Handoff', 'Default', 4, None, None, None, 1, 'john from cincinnati'),
#  ('Looking', None, 'Handoff', 'Default', 4, None, None, None, 1, 'looking'),
#  ('Magnifica 70', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'magnifica 70'),
#  ('Mildred Pierce', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'mildred pierce'),
#  ('ONE-NIGHT STAND', None, 'Handoff', 'Default', 4, None, None, None, 1, 'one-night stand'),
#  ('Olive Kitteridge', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'olive kitteridge'),
#  ('Outcast', None, 'Handoff', 'Default', 4, None, None, None, 0, 'outcast'),
#  ("Parade's End", None, 'Jumpstart', 'Default', 2, None, None, None, 0, "parade's end"),
#  ('Pinky Dinky Doo', None, 'Handoff', 'Default', 4, None, None, None, 1, 'pinky dinky doo'),
#  ('Psi', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'psi'),
#  ('Real Time with Bill Maher', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'real time with bill maher'),
#  ('Real Time with Bill Maher', None, 'Handoff', 'Default', 4, None, None, None, 1, 'real time with bill maher'),
#  ('Saving My Tomorrow', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'saving my tomorrow'),
#  ('Single Long', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'single long'),
#  ('Sr. Avila', None, 'Handoff', 'Default', 4, None, None, None, 1, 'sr. avila'),
#  ('The Brink', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'the brink'),
#  ('The Brink', None, 'Handoff', 'Default', 4, None, None, None, 1, 'the brink'),
#  ('The Casual Vacancy', None, 'Handoff', 'Default', 4, None, None, None, 0, 'the casual vacancy'),
#  ('The Casual Vacancy', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'the casual vacancy'),
#  ('The Comeback', None, 'Handoff', 'Default', 4, None, None, None, 1, 'the comeback'),
#  ('The Comeback', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'the comeback'),
#  ('The Electric Company', None, 'Handoff', 'Default', 4, None, None, None, 1, 'the electric company'),
#  ('The Knick', None, 'Handoff', 'Default', 4, None, None, None, 1, 'the knick'),
#  ('The Larry Sanders Show', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'the larry sanders show'),
#  ("The No. 1 Ladies' Detective Agency", None, 'Jumpstart', 'Default', 2, None, None, None, 1, "the no. 1 ladies' detective agency"),
#  ('The Teenage Psychic', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'the teenage psychic'),
#  ('The Weight of the Nation for Kids', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'the weight of the nation for kids'),
#  ('The Wire', None, 'Handoff', 'Default', 4, None, None, None, 1, 'the wire'),
#  ('The Young Pope', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'the young pope'),
#  ('The Young Pope', None, 'Handoff', 'Default', 4, None, None, None, 1, 'the young pope'),
#  ('Togetherness', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'togetherness'),
#  ('True Blood', None, 'Handoff', 'Default', 4, None, None, None, 1, 'true blood'),
#  ('True Blood', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'true blood'),
#  ('True Detective', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'true detective'),
#  ('Vice Special Reports', None, 'Handoff', 'Default', 4, None, None, None, 0, 'vice special reports'),
#  ('We Can Be Heroes', None, 'Handoff', 'Default', 4, None, None, None, 0, 'we can be heroes'),
#  ('We Can Be Heroes', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'we can be heroes'),
#  ('Westworld', None, 'Handoff', 'Default', 2, None, None, None, 1, 'westworld'),
#  ('A Little Curious', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'a little curious'),
#  ('After the Thrones', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'after the thrones'),
#  ('Alice', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'alice'),
#  ('Alice', None, 'Handoff', 'Default', 4, None, None, None, 1, 'alice'),
#  ('Angels in America', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'angels in america'),
#  ('Angry Boys', None, 'Handoff', 'Default', 4, None, None, None, 1, 'angry boys'),
#  ('Animals.', None, 'Handoff', 'Default', 4, None, None, None, 1, 'animals.'),
#  ('Any Given Wednesday with Bill Simmons', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'any given wednesday with bill simmons'),
#  ('Band of Brothers', None, 'Handoff', 'Default', 4, None, None, None, 1, 'band of brothers'),
#  ('Big Love', None, 'Handoff', 'Default', 4, None, None, None, 1, 'big love'),
#  ('Boardwalk Empire', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'boardwalk empire'),
#  ('Bored to Death', None, 'Handoff', 'Default', 4, None, None, None, 1, 'bored to death'),
#  ('CATHOUSE: THE SERIES', None, 'Handoff', 'Default', 4, None, None, None, 1, 'cathouse: the series'),
#  ('CATHOUSE: THE SERIES', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'cathouse: the series'),
#  ('Capadocia', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'capadocia'),
#  ('Chumel con Chumel Torres', None, 'Handoff', 'Default', 4, None, None, None, 1, 'chumel con chumel torres'),
#  ('Crashbox', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'crashbox'),
#  ('Curb Your Enthusiasm', None, 'Handoff', 'Default', 4, None, None, None, 1, 'curb your enthusiasm'),
#  ('DOWN + DIRTY WITH JIM NORTON', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'down + dirty with jim norton'),
#  ('Dios Inc.', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'dios inc.'),
#  ('Divorce', None, 'Jumpstart', 'Default', 4, 'current_season', None, None, 1, 'divorce'),
#  ('El Negocio', None, 'Jumpstart', 'Default', 2, None, None, None, 1, 'el negocio'),
#  ('Empire Falls', None, 'Jumpstart', 'Default', 2, None, None, None, 0, 'empire falls')]

# %%
campAttribs = _.DataFrame()

# %%
campAttribs
# Out:
#                              asset_series subscription_state   behavior  \
# 0                           2 Dope Queens               None  Jumpstart
# 1                          All Def Comedy               None  Jumpstart
# 2                              Angry Boys               None  Jumpstart
# 3   Any Given Wednesday with Bill Simmons               None    Handoff
# 4                                 Ballers               None    Handoff
# 5                                 Ballers               None  Jumpstart
# 6                         Big Little Lies               None  Jumpstart
# 7                        Boardwalk Empire               None    Handoff
# 8                               Capadocia               None    Handoff
# 9                               Carnivale               None  Jumpstart
# 10                         Classical Baby               None  Jumpstart
# 11                               Crashing               None  Jumpstart
# 12                   DANE COOK'S TOURGASM               None    Handoff
# 13                               Deadwood               None  Jumpstart
# 14                               Deadwood               None    Handoff
# 15                        Destino: Brazil               None  Jumpstart
# 16                              Dios Inc.               None    Handoff
# 17                                Divorce               None    Handoff
# 18                       Eastbound & Down               None  Jumpstart
# 19                        El Hipnotizador               None  Jumpstart
# 20                    El Jardin de Bronce               None  Jumpstart
# 21                    El Jardin de Bronce               None    Handoff
# 22                             El Negocio               None    Handoff
# 23                              Epitafios               None    Handoff
# 24                                 Extras               None  Jumpstart
# 25                         Fantasmagorias               None  Jumpstart
# 26                           Fraggle Rock               None    Handoff
# 27                             Getting On               None  Jumpstart
# 28                                  Girls               None  Jumpstart
# 29                     Gran'pa Knows Best               None    Handoff
# ..                                    ...                ...        ...
# 70                             True Blood               None    Handoff
# 71                             True Blood               None  Jumpstart
# 72                         True Detective               None  Jumpstart
# 73                   Vice Special Reports               None    Handoff
# 74                       We Can Be Heroes               None    Handoff
# 75                       We Can Be Heroes               None  Jumpstart
# 76                              Westworld               None    Handoff
# 77                       A Little Curious               None  Jumpstart
# 78                      After the Thrones               None  Jumpstart
# 79                                  Alice               None  Jumpstart
# 80                                  Alice               None    Handoff
# 81                      Angels in America               None  Jumpstart
# 82                             Angry Boys               None    Handoff
# 83                               Animals.               None    Handoff
# 84  Any Given Wednesday with Bill Simmons               None  Jumpstart
# 85                       Band of Brothers               None    Handoff
# 86                               Big Love               None    Handoff
# 87                       Boardwalk Empire               None  Jumpstart
# 88                         Bored to Death               None    Handoff
# 89                   CATHOUSE: THE SERIES               None    Handoff
# 90                   CATHOUSE: THE SERIES               None  Jumpstart
# 91                              Capadocia               None  Jumpstart
# 92               Chumel con Chumel Torres               None    Handoff
# 93                               Crashbox               None  Jumpstart
# 94                   Curb Your Enthusiasm               None    Handoff
# 95           DOWN + DIRTY WITH JIM NORTON               None  Jumpstart
# 96                              Dios Inc.               None  Jumpstart
# 97                                Divorce               None  Jumpstart
# 98                             El Negocio               None  Jumpstart
# 99                           Empire Falls               None  Jumpstart
#
#    campaign_type  episodes          season start_date end_date  active  \
# 0        Default         2            None       None     None       0
# 1        Default         2            None       None     None       1
# 2        Default         2            None       None     None       1
# 3        Default         4            None       None     None       1
# 4        Default         4            None       None     None       1
# 5        Default         2            None       None     None       1
# 6        Default         2            None       None     None       1
# 7        Default         4            None       None     None       1
# 8        Default         4            None       None     None       1
# 9        Default         2            None       None     None       1
# 10       Default         2            None       None     None       0
# 11       Default         4  current_season       None     None       1
# 12       Default         4            None       None     None       1
# 13       Default         2            None       None     None       1
# 14       Default         4            None       None     None       1
# 15       Default         2            None       None     None       0
# 16       Default         4            None       None     None       1
# 17       Default         1            None       None     None       1
# 18       Default         2            None       None     None       1
# 19       Default         2            None       None     None       1
# 20       Default         2            None       None     None       1
# 21       Default         4            None       None     None       1
# 22       Default         4            None       None     None       1
# 23       Default         4            None       None     None       1
# 24       Default         2            None       None     None       1
# 25       Default         2            None       None     None       1
# 26       Default         4            None       None     None       1
# 27       Default         2            None       None     None       1
# 28       Default         2            None       None     None       1
# 29       Default         4            None       None     None       1
# ..           ...       ...             ...        ...      ...     ...
# 70       Default         4            None       None     None       1
# 71       Default         2            None       None     None       1
# 72       Default         2            None       None     None       1
# 73       Default         4            None       None     None       0
# 74       Default         4            None       None     None       0
# 75       Default         2            None       None     None       0
# 76       Default         2            None       None     None       1
# 77       Default         2            None       None     None       1
# 78       Default         2            None       None     None       1
# 79       Default         2            None       None     None       1
# 80       Default         4            None       None     None       1
# 81       Default         2            None       None     None       0
# 82       Default         4            None       None     None       1
# 83       Default         4            None       None     None       1
# 84       Default         2            None       None     None       1
# 85       Default         4            None       None     None       1
# 86       Default         4            None       None     None       1
# 87       Default         2            None       None     None       1
# 88       Default         4            None       None     None       1
# 89       Default         4            None       None     None       1
# 90       Default         2            None       None     None       1
# 91       Default         2            None       None     None       1
# 92       Default         4            None       None     None       1
# 93       Default         2            None       None     None       1
# 94       Default         4            None       None     None       1
# 95       Default         2            None       None     None       0
# 96       Default         2            None       None     None       1
# 97       Default         4  current_season       None     None       1
# 98       Default         2            None       None     None       1
# 99       Default         2            None       None     None       0
#
#                     appboy_attribute_name
# 0                           2 dope queens
# 1                          all def comedy
# 2                              angry boys
# 3   any given wednesday with bill simmons
# 4                                 ballers
# 5                                 ballers
# 6                         big little lies
# 7                        boardwalk empire
# 8                               capadocia
# 9                               carnivale
# 10                         classical baby
# 11                               crashing
# 12                   dane cook's tourgasm
# 13                               deadwood
# 14                               deadwood
# 15                        destino: brazil
# 16                              dios inc.
# 17                                divorce
# 18                       eastbound & down
# 19                        el hipnotizador
# 20                    el jardin de bronce
# 21                    el jardin de bronce
# 22                             el negocio
# 23                              epitafios
# 24                                 extras
# 25                         fantasmagorias
# 26                           fraggle rock
# 27                             getting on
# 28                                  girls
# 29                     gran'pa knows best
# ..                                    ...
# 70                             true blood
# 71                             true blood
# 72                         true detective
# 73                   vice special reports
# 74                       we can be heroes
# 75                       we can be heroes
# 76                              westworld
# 77                       a little curious
# 78                      after the thrones
# 79                                  alice
# 80                                  alice
# 81                      angels in america
# 82                             angry boys
# 83                               animals.
# 84  any given wednesday with bill simmons
# 85                       band of brothers
# 86                               big love
# 87                       boardwalk empire
# 88                         bored to death
# 89                   cathouse: the series
# 90                   cathouse: the series
# 91                              capadocia
# 92               chumel con chumel torres
# 93                               crashbox
# 94                   curb your enthusiasm
# 95           down + dirty with jim norton
# 96                              dios inc.
# 97                                divorce
# 98                             el negocio
# 99                           empire falls
#
# [100 rows x 10 columns]
